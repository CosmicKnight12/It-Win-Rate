# %%
#importing necessaery libraries
import pandas as pd
import numpy as nm

# %%
#reading data into a data frame df
df = pd.read_excel('Win_Prediction_Data_Team 1.xlsx')

# %%
#checking the first 5 values
df.head()
# Out:
#   Client Category Solution Type  Deal Date     Sector Location      VP Name  \
# 0         Telecom    Solution 7 2012-03-27  Sector 24       L5  Ekta Zutshi
# 1         Telecom    Solution 7 2012-09-25  Sector 24       L5  Ekta Zutshi
# 2        Internal   Solution 59 2011-08-01  Sector 20   Others  Ekta Zutshi
# 3        Internal   Solution 59 2011-04-28  Sector 20   Others  Ekta Zutshi
# 4        Internal   Solution 32 2011-06-03  Sector 20   Others  Ekta Zutshi
#
#       Manager Name  Deal Cost Deal Status Code
# 0  Gopa Trilochana  150000.00              Won
# 1  Gopa Trilochana  744705.88              Won
# 2   Russell Dahlen   60000.00             Lost
# 3   Russell Dahlen   60000.00             Lost
# 4   Russell Dahlen   80882.35             Lost

# %%
#checking last 5 values
df.tail()
# Out:
#       Client Category Solution Type  Deal Date     Sector Location  \
# 10056       Power ind    Solution 9 2019-03-18   Sector 9       L5
# 10057        Internal    Solution 6 2019-03-04  Sector 20   Others
# 10058       Power ind    Solution 9 2019-02-28   Sector 9       L5
# 10059       Power ind   Solution 62 2019-01-27   Sector 9       L5
# 10060          Others    Solution 9 2019-05-30  Sector 12      L10
#
#                VP Name     Manager Name   Deal Cost Deal Status Code
# 10056  Rudraksh Sharma  Rudraksh Sharma   588235.29             Lost
# 10057  Rudraksh Sharma   Sharavan Singh   777058.82              Won
# 10058  Rudraksh Sharma  Rudraksh Sharma   588235.29             Lost
# 10059      Man Suddeth  Cleotilde Biron  3042058.82              Won
# 10060  Son Mcconnaughy       Tarun Garg   147058.82             Lost

# %%
df.dtypes
# Out:
# Client Category             object
# Solution Type               object
# Deal Date           datetime64[ns]
# Sector                      object
# Location                    object
# VP Name                     object
# Manager Name                object
# Deal Cost                  float64
# Deal Status Code            object
# dtype: object

# %%
duplicates=df.duplicated()

# %%
print(df[duplicates])
# Out:
#             Client Category Solution Type  Deal Date     Sector Location  \
# 3036   Domestic Public Bank   Solution 32 2015-03-20   Sector 2       L7
# 3385                   Tech   Solution 32 2015-07-31   Sector 2      L10
# 3880                Telecom   Solution 12 2013-08-30  Sector 24   Others
# 5037                   Tech   Solution 13 2012-05-08  Sector 23       L5
# 7637                   Govt   Solution 34 2018-02-21   Sector 4      L10
# 7705               Internal    Solution 9 2015-01-06  Sector 20   Others
# 7718         Services_based   Solution 26 2018-02-11  Sector 17      L10
# 8020               Internal    Solution 9 2015-07-02   Sector 2       L9
# 8167         Infrastructure    Solution 9 2015-05-18  Sector 24      L10
# 8177         Services_based    Solution 9 2015-10-03  Sector 23       L1
# 8730                 Others    Solution 9 2016-06-14  Sector 23       L4
# 8905  Domestic Private Bank    Solution 9 2016-08-22   Sector 2       L1
# ...

# %%
df = df.drop_duplicates()

# %%
df.head()
# Out:
#   Client Category Solution Type  Deal Date     Sector Location      VP Name  \
# 0         Telecom    Solution 7 2012-03-27  Sector 24       L5  Ekta Zutshi
# 1         Telecom    Solution 7 2012-09-25  Sector 24       L5  Ekta Zutshi
# 2        Internal   Solution 59 2011-08-01  Sector 20   Others  Ekta Zutshi
# 3        Internal   Solution 59 2011-04-28  Sector 20   Others  Ekta Zutshi
# 4        Internal   Solution 32 2011-06-03  Sector 20   Others  Ekta Zutshi
#
#       Manager Name  Deal Cost Deal Status Code
# 0  Gopa Trilochana  150000.00              Won
# 1  Gopa Trilochana  744705.88              Won
# 2   Russell Dahlen   60000.00             Lost
# 3   Russell Dahlen   60000.00             Lost
# 4   Russell Dahlen   80882.35             Lost

# %%
df.tail()
# Out:
#       Client Category Solution Type  Deal Date     Sector Location  \
# 10056       Power ind    Solution 9 2019-03-18   Sector 9       L5
# 10057        Internal    Solution 6 2019-03-04  Sector 20   Others
# 10058       Power ind    Solution 9 2019-02-28   Sector 9       L5
# 10059       Power ind   Solution 62 2019-01-27   Sector 9       L5
# 10060          Others    Solution 9 2019-05-30  Sector 12      L10
#
#                VP Name     Manager Name   Deal Cost Deal Status Code
# 10056  Rudraksh Sharma  Rudraksh Sharma   588235.29             Lost
# 10057  Rudraksh Sharma   Sharavan Singh   777058.82              Won
# 10058  Rudraksh Sharma  Rudraksh Sharma   588235.29             Lost
# 10059      Man Suddeth  Cleotilde Biron  3042058.82              Won
# 10060  Son Mcconnaughy       Tarun Garg   147058.82             Lost

# %%
duplicates=df.duplicated()

# %%
print(df[duplicates])
# Out:
# Empty DataFrame
# Columns: [Client Category, Solution Type, Deal Date, Sector, Location, VP Name, Manager Name, Deal Cost, Deal Status Code]
# Index: []

# %%
total_rows = df.shape[0]

print(f'Total rows: {total_rows}')
# Out:
# Total rows: 10047

# %%
missing_values = df.isnull().sum()

print(missing_values)
# Out:
# Client Category     79
# Solution Type        0
# Deal Date            0
# Sector               0
# Location             0
# VP Name              0
# Manager Name         0
# Deal Cost            0
# Deal Status Code     0
# dtype: int64

# %%
rows_with_missing_values = df[df.isnull().any(axis=1)]

print(rows_with_missing_values)
# Out:
#      Client Category Solution Type  Deal Date     Sector Location  \
# 488              NaN    Solution 7 2018-10-05  Sector 12      L10
# 491              NaN    Solution 7 2019-01-06  Sector 12      L10
# 518              NaN   Solution 10 2012-01-12  Sector 19      L10
# 732              NaN   Solution 10 2013-11-08  Sector 23      L10
# 1128             NaN   Solution 37 2013-09-27  Sector 24      L10
# ...              ...           ...        ...        ...      ...
# 9477             NaN   Solution 32 2018-09-26  Sector 23      L10
# 9753             NaN    Solution 9 2018-08-04  Sector 19      L10
# 9819             NaN    Solution 9 2018-09-15  Sector 19      L10
# 9904             NaN   Solution 14 2018-11-29  Sector 12      L10
# 9993             NaN    Solution 9 2019-02-09  Sector 24      L10
#
#                VP Name     Manager Name  Deal Cost Deal Status Code
# 488    Ankita Aggarwal    Kizzie Troxel  441176.47             Lost
# ...

# %%
null_values = df[df['Client Category'].isnull()]

# Step 2: Display the count of missing values for each sector
count_occurrences = null_values['Sector'].value_counts().reset_index(name='Count').rename(columns={'index': 'Sector'})

# Display the result
print(count_occurrences)
# Out:
#       Sector  Count
# 0  Sector 24     28
# 1  Sector 19     15
# 2  Sector 12     10
# 3  Sector 23      8
# 4   Sector 6      6
# 5   Sector 3      4
# 6  Sector 15      4
# 7   Sector 5      2
# 8  Sector 20      2

# %%
df['Client Category'] = df.groupby('Sector')['Client Category'].transform(lambda x: x.fillna(x.mode()[0]))

# %%
missing_values = df.isnull().sum()

print(missing_values)
# Out:
# Client Category     0
# Solution Type       0
# Deal Date           0
# Sector              0
# Location            0
# VP Name             0
# Manager Name        0
# Deal Cost           0
# Deal Status Code    0
# dtype: int64

# %%
print(df)
# Out:
#       Client Category Solution Type  Deal Date     Sector Location  \
# 0             Telecom    Solution 7 2012-03-27  Sector 24       L5
# 1             Telecom    Solution 7 2012-09-25  Sector 24       L5
# 2            Internal   Solution 59 2011-08-01  Sector 20   Others
# 3            Internal   Solution 59 2011-04-28  Sector 20   Others
# 4            Internal   Solution 32 2011-06-03  Sector 20   Others
# ...               ...           ...        ...        ...      ...
# 10056       Power ind    Solution 9 2019-03-18   Sector 9       L5
# 10057        Internal    Solution 6 2019-03-04  Sector 20   Others
# 10058       Power ind    Solution 9 2019-02-28   Sector 9       L5
# 10059       Power ind   Solution 62 2019-01-27   Sector 9       L5
# 10060          Others    Solution 9 2019-05-30  Sector 12      L10
#
#                VP Name     Manager Name   Deal Cost Deal Status Code
# 0          Ekta Zutshi  Gopa Trilochana   150000.00              Won
# ...

# %%
print(df.iloc[[488,491,518]])
# Out:
#     Client Category Solution Type  Deal Date     Sector Location  \
# 488   Consumer Good    Solution 7 2018-10-05  Sector 12      L10
# 491   Consumer Good    Solution 7 2019-01-06  Sector 12      L10
# 518   Media_Journal   Solution 10 2012-01-12  Sector 19      L10
#
#               VP Name    Manager Name  Deal Cost Deal Status Code
# 488   Ankita Aggarwal   Kizzie Troxel  441176.47             Lost
# 491   Ankita Aggarwal   Kizzie Troxel  441176.47             Lost
# 518  Mangesh K. Singh  Hardeep Suksma   38235.29              Won

# %%
import matplotlib.pyplot as plt 
import seaborn as sns
from scipy import stats
from scipy.stats import skew

# %%
df.head()
# Out:
#   Client Category Solution Type  Deal Date     Sector Location      VP Name  \
# 0         Telecom    Solution 7 2012-03-27  Sector 24       L5  Ekta Zutshi
# 1         Telecom    Solution 7 2012-09-25  Sector 24       L5  Ekta Zutshi
# 2        Internal   Solution 59 2011-08-01  Sector 20   Others  Ekta Zutshi
# 3        Internal   Solution 59 2011-04-28  Sector 20   Others  Ekta Zutshi
# 4        Internal   Solution 32 2011-06-03  Sector 20   Others  Ekta Zutshi
#
#       Manager Name  Deal Cost Deal Status Code
# 0  Gopa Trilochana  150000.00              Won
# 1  Gopa Trilochana  744705.88              Won
# 2   Russell Dahlen   60000.00             Lost
# 3   Russell Dahlen   60000.00             Lost
# 4   Russell Dahlen   80882.35             Lost

# %%
df_cp = df

# %%
plt.figure(figsize=(15, 6))
sns.histplot(df_cp['Deal Cost'], kde=True)

plt.title('Histogram of Deal Cost')
plt.xlabel('Deal Cost')
print(skew(df_cp['Deal Cost']))
plt.show()
# Out:
# 9.729098693092144

# %%
print(f"min: {df_cp['Deal Cost'].min()}")


print(f"max: {df_cp['Deal Cost'].max()}")

print(df['Deal Cost'].value_counts()[0])

# Calculate mean
mean = df_cp['Deal Cost'].mean()

# Calculate median
median = df_cp['Deal Cost'].median()

# Calculate mode
mode = df_cp['Deal Cost'].mode()[0]

print(f"Mean: {mean}, Median: {median}, Mode: {mode}")
# Out:
# min: 0.0
# max: 36764705.88
# 245
# Mean: 767296.3253856872, Median: 382352.94, Mode: 294117.65

# %%
df_cp['Deal Cost'], fitted_lambda = stats.boxcox(df_cp['Deal Cost']+0.0001)

# Print the optimal lambda value
print(f"Lambda value used for Transformation: {fitted_lambda}")
# Out:
# Lambda value used for Transformation: 0.23582863995591516

# %%
df_cp
# Out:
#       Client Category Solution Type  Deal Date     Sector Location  \
# 0             Telecom    Solution 7 2012-03-27  Sector 24       L5
# 1             Telecom    Solution 7 2012-09-25  Sector 24       L5
# 2            Internal   Solution 59 2011-08-01  Sector 20   Others
# 3            Internal   Solution 59 2011-04-28  Sector 20   Others
# 4            Internal   Solution 32 2011-06-03  Sector 20   Others
# ...               ...           ...        ...        ...      ...
# 10056       Power ind    Solution 9 2019-03-18   Sector 9       L5
# 10057        Internal    Solution 6 2019-03-04  Sector 20   Others
# 10058       Power ind    Solution 9 2019-02-28   Sector 9       L5
# 10059       Power ind   Solution 62 2019-01-27   Sector 9       L5
# 10060          Others    Solution 9 2019-05-30  Sector 12      L10
#
#                VP Name     Manager Name   Deal Cost Deal Status Code
# 0          Ekta Zutshi  Gopa Trilochana   66.240951              Won
# ...

# %%
df
# Out:
#       Client Category Solution Type  Deal Date     Sector Location  \
# 0             Telecom    Solution 7 2012-03-27  Sector 24       L5
# 1             Telecom    Solution 7 2012-09-25  Sector 24       L5
# 2            Internal   Solution 59 2011-08-01  Sector 20   Others
# 3            Internal   Solution 59 2011-04-28  Sector 20   Others
# 4            Internal   Solution 32 2011-06-03  Sector 20   Others
# ...               ...           ...        ...        ...      ...
# 10056       Power ind    Solution 9 2019-03-18   Sector 9       L5
# 10057        Internal    Solution 6 2019-03-04  Sector 20   Others
# 10058       Power ind    Solution 9 2019-02-28   Sector 9       L5
# 10059       Power ind   Solution 62 2019-01-27   Sector 9       L5
# 10060          Others    Solution 9 2019-05-30  Sector 12      L10
#
#                VP Name     Manager Name   Deal Cost Deal Status Code
# 0          Ekta Zutshi  Gopa Trilochana   66.240951              Won
# ...

# %%
plt.figure(figsize=(15, 6))
sns.histplot(df_cp['Deal Cost'], kde=True)

plt.title('Histogram of Deal Cost')
plt.xlabel('Deal Cost')
print(skew(df_cp['Deal Cost']))
plt.show()
# Out:
# 0.11938701977448679

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(x=df_cp['Deal Cost'])

plt.title('Boxplot of Deal Cost')
plt.xlabel('Deal Cost')

plt.show()

# %%
print(f"min: {df_cp['Deal Cost'].min()}")


print(f"max: {df_cp['Deal Cost'].max()}")

# Calculate mean
mean = df_cp['Deal Cost'].mean()

# Calculate median
median = df_cp['Deal Cost'].median()

# Calculate mode
mode = df_cp['Deal Cost'].mode()[0]

print(f"Mean: {mean}, Median: {median}, Mode: {mode}")
# Out:
# min: -3.7572093868081127
# max: 253.71750138545656
# Mean: 85.09088884724831, Median: 83.64335635649088, Mode: 78.37053114702316

# %%
Q1 = df_cp['Deal Cost'].quantile(0.25)
Q3 = df_cp['Deal Cost'].quantile(0.75)
IQR = Q3 - Q1

# Define limits
lower_limit = Q1 - 1.5 * IQR
upper_limit = Q3 + 1.5 * IQR
outlier = df_cp[(df_cp['Deal Cost'] < lower_limit) | (df_cp['Deal Cost'] > upper_limit)]
print(outlier)
# Out:
#              Client Category Solution Type  Deal Date     Sector Location  \
# 13             Manufacturing   Solution 59 2011-12-20  Sector 15       L5
# 40             Manufacturing   Solution 59 2012-02-20  Sector 15       L5
# 43     Domestic Private Bank    Solution 7 2015-05-27   Sector 2      L10
# 45     Domestic Private Bank    Solution 7 2015-05-06   Sector 2      L10
# 57                      Govt   Solution 59 2012-01-09  Sector 12       L5
# ...                      ...           ...        ...        ...      ...
# 9930    Domestic Public Bank    Solution 9 2019-03-13   Sector 2      L10
# 9934    Domestic Public Bank    Solution 9 2018-12-25   Sector 2      L10
# 9975                  Others    Solution 9 2019-01-16  Sector 23       L5
# 10005  Domestic Private Bank   Solution 49 2018-11-29   Sector 2      L10
# 10053              Power ind    Solution 9 2019-03-25   Sector 9       L5
#
#                VP Name   Manager Name   Deal Cost Deal Status Code
# ...

# %%
print(upper_limit)
# Out:
# 142.8251396535265

# %%
print(lower_limit)
# Out:
# 26.62477727038732

# %%
df_cp['Deal Cost'] = df_cp['Deal Cost'].clip(lower_limit, upper_limit)

# %%
print(df_cp.iloc[[13,43,1005,10040]])
# Out:
#              Client Category Solution Type  Deal Date     Sector Location  \
# 13             Manufacturing   Solution 59 2011-12-20  Sector 15       L5
# 43     Domestic Private Bank    Solution 7 2015-05-27   Sector 2      L10
# 1005   Domestic Private Bank   Solution 37 2013-10-28   Sector 2       L4
# 10054                Telecom    Solution 4 2019-01-23  Sector 24       L5
#
#               VP Name     Manager Name   Deal Cost Deal Status Code
# 13        Ekta Zutshi         shafibul  142.825140             Lost
# 43     Mervin Harwood        D. Ankit    26.624777             Lost
# 1005   Rosanna Maynez  Abhinav Warrier   93.269360              Won
# 10054    Rahul Bajpai   Abhiskek Kumar   52.279379              Won

# %%
plt.figure(figsize=(15, 6))
sns.histplot(df_cp['Deal Cost'], kde=True)

plt.title('Histogram of Deal Cost')
plt.xlabel('Deal Cost')
print(skew(df_cp['Deal Cost']))
plt.show()
# Out:
# 0.07761612122643718

# %%
df
# Out:
#       Client Category Solution Type  Deal Date     Sector Location  \
# 0             Telecom    Solution 7 2012-03-27  Sector 24       L5
# 1             Telecom    Solution 7 2012-09-25  Sector 24       L5
# 2            Internal   Solution 59 2011-08-01  Sector 20   Others
# 3            Internal   Solution 59 2011-04-28  Sector 20   Others
# 4            Internal   Solution 32 2011-06-03  Sector 20   Others
# ...               ...           ...        ...        ...      ...
# 10056       Power ind    Solution 9 2019-03-18   Sector 9       L5
# 10057        Internal    Solution 6 2019-03-04  Sector 20   Others
# 10058       Power ind    Solution 9 2019-02-28   Sector 9       L5
# 10059       Power ind   Solution 62 2019-01-27   Sector 9       L5
# 10060          Others    Solution 9 2019-05-30  Sector 12      L10
#
#                VP Name     Manager Name   Deal Cost Deal Status Code
# 0          Ekta Zutshi  Gopa Trilochana   66.240951              Won
# ...

# %%
value_counts = df['Deal Status Code'].value_counts()

# Create a pie chart
value_counts.plot(kind='pie', autopct='%1.1f%%')

# Set the title
plt.title('Percentage of Won and Lost Deals')

# Show the plot
plt.show()

# %%
import seaborn as sns

# %%
win_rates = df.groupby('Location')['Deal Status Code'].apply(lambda x: (x == 'Won').mean())

# Sort the win rates in descending order for better visualization
win_rates = win_rates.sort_values(ascending=False)

# Plot the results
win_rates.plot(kind='barh', figsize=(10,10))
plt.xlabel('Win Rate')
plt.ylabel('Location')
plt.show()

# %%
win_rates = df.groupby('Client Category')['Deal Status Code'].apply(lambda x: (x == 'Won').mean())

# Sort the win rates in descending order for better visualization
win_rates = win_rates.sort_values(ascending=False)

# Plot the results
win_rates.plot(kind='barh', figsize=(10,10))
plt.xlabel('Win Rate')
plt.ylabel('Client Category')
plt.show()

# %%
win_rates = df.groupby('Sector')['Deal Status Code'].apply(lambda x: (x == 'Won').mean())

# Sort the win rates in descending order for better visualization
win_rates = win_rates.sort_values(ascending=False)

# Plot the results
win_rates.plot(kind='barh', figsize=(10,10))
plt.xlabel('Win Rate')
plt.ylabel('Sector')
plt.show()

# %%
# Assuming df is your DataFrame, 'column1' is the column with 'yes' and 'no' values, and 'column2' is the other column
pivot_table = df.pivot_table(index='Client Category', columns='Deal Status Code', aggfunc='size')

# Calculate the percentage of 'yes' and 'no' values
pivot_table['won_percentage'] = pivot_table['Won'] / (pivot_table['Won'] + pivot_table['Lost']) * 100
pivot_table['lost_percentage'] = pivot_table['Lost'] / (pivot_table['Won'] + pivot_table['Lost']) * 100

# Sort the pivot table in descending order of 'yes' values
sorted_pivot_table = pivot_table.sort_values('won_percentage', ascending=False)

print(sorted_pivot_table)
# Out:
# Deal Status Code       Lost  Won  won_percentage  lost_percentage
# Client Category
# Share_market              4   10       71.428571        28.571429
# Internal                693  760       52.305575        47.694425
# Management               22   21       48.837209        51.162791
# Consulting              182  170       48.295455        51.704545
# Consumer Good           106   89       45.641026        54.358974
# Holding                  14   11       44.000000        56.000000
# Energy                   32   25       43.859649        56.140351
# International Bank      215  160       42.666667        57.333333
# Power ind               152  112       42.424242        57.575758
# Infrastructure           87   64       42.384106        57.615894
# Media_Journal            50   36       41.860465        58.139535
# Domestic Bank            78   56       41.791045        58.208955
# Telecom                 213  141       39.830508        60.169492
# ...

# %%
# Assuming df is your DataFrame, 'column1' is the column with 'yes' and 'no' values, and 'column2' is the other column
pivot_table = df.pivot_table(index='Sector', columns='Deal Status Code', aggfunc='size')

# Calculate the percentage of 'yes' and 'no' values
pivot_table['won_percentage'] = pivot_table['Won'] / (pivot_table['Won'] + pivot_table['Lost']) * 100
pivot_table['lost_percentage'] = pivot_table['Lost'] / (pivot_table['Won'] + pivot_table['Lost']) * 100

# Sort the pivot table in descending order of 'yes' values
sorted_pivot_table = pivot_table.sort_values('won_percentage', ascending=False)

print(sorted_pivot_table)
# Out:
# Deal Status Code  Lost   Won  won_percentage  lost_percentage
# Sector
# Sector 21           10    20       66.666667        33.333333
# Sector 7             6     8       57.142857        42.857143
# Sector 20          382   389       50.453956        49.546044
# Sector 9           202   167       45.257453        54.742547
# Sector 17          273   200       42.283298        57.716702
# Sector 19           84    58       40.845070        59.154930
# Sector 15          234   153       39.534884        60.465116
# Sector 23         1637  1053       39.144981        60.855019
# Sector 24          358   218       37.847222        62.152778
# Sector 22           90    54       37.500000        62.500000
# Sector 6            62    34       35.416667        64.583333
# Sector 25          178    95       34.798535        65.201465
# Sector 2          1147   596       34.193919        65.806081
# Sector 16          316   158       33.333333        66.666667
# ...

# %%
# Assuming df is your DataFrame, 'column1' is the column with 'yes' and 'no' values, and 'column2' is the other column
pivot_table = df.pivot_table(index='Location', columns='Deal Status Code', aggfunc='size')

# Calculate the percentage of 'yes' and 'no' values
pivot_table['won_percentage'] = pivot_table['Won'] / (pivot_table['Won'] + pivot_table['Lost']) * 100
pivot_table['lost_percentage'] = pivot_table['Lost'] / (pivot_table['Won'] + pivot_table['Lost']) * 100

# Sort the pivot table in descending order of 'yes' values
sorted_pivot_table = pivot_table.sort_values('won_percentage', ascending=False)

print(sorted_pivot_table)
# Out:
# Deal Status Code  Lost   Won  won_percentage  lost_percentage
# Location
# Others             423   391       48.034398        51.965602
# L1                 910   660       42.038217        57.961783
# L5                1391   936       40.223464        59.776536
# L11                232   135       36.784741        63.215259
# L3                 356   200       35.971223        64.028777
# L12                178    98       35.507246        64.492754
# L10               2225  1130       33.681073        66.318927
# L4                 125    62       33.155080        66.844920
# L6                  70    30       30.000000        70.000000
# L7                 173    64       27.004219        72.995781
# L2                   6     2       25.000000        75.000000
# L9                 193    46       19.246862        80.753138
# L8                  10     1        9.090909        90.909091

# %%
# Assuming df is your DataFrame, 'column1' is the column with 'yes' and 'no' values, and 'column2' is the other column
pivot_table = df.pivot_table(index='VP Name', columns='Deal Status Code', aggfunc='size')

# Calculate the percentage of 'yes' and 'no' values
pivot_table['won_percentage'] = pivot_table['Won'] / (pivot_table['Won'] + pivot_table['Lost']) * 100
pivot_table['lost_percentage'] = pivot_table['Lost'] / (pivot_table['Won'] + pivot_table['Lost']) * 100

# Sort the pivot table in descending order of 'yes' values
sorted_pivot_table = pivot_table.sort_values('won_percentage', ascending=False)

print(sorted_pivot_table)
# Out:
# Deal Status Code      Lost    Won  won_percentage  lost_percentage
# VP Name
# Ekta Zutshi          206.0  344.0       62.545455        37.454545
# Prashant Rawat        12.0   15.0       55.555556        44.444444
# Vikram Rawat           8.0    9.0       52.941176        47.058824
# Long Bergstrom       449.0  471.0       51.195652        48.804348
# Alam Syed             62.0   64.0       50.793651        49.206349
# Molly Eakes           65.0   60.0       48.000000        52.000000
# Lilli Storrs          14.0   12.0       46.153846        53.846154
# neeraj kumar         254.0  217.0       46.072187        53.927813
# Man Suddeth           16.0   13.0       44.827586        55.172414
# Jitendra Choudhary    16.0   12.0       42.857143        57.142857
# Varsha Arora          60.0   44.0       42.307692        57.692308
# Gaurav Sameria        66.0   48.0       42.105263        57.894737
# Vidur Hukle           58.0   42.0       42.000000        58.000000
# ...

# %%
# Assuming df is your DataFrame, 'column1' is the column with 'yes' and 'no' values, and 'column2' is the other column
pivot_table = df.pivot_table(index='Manager Name', columns='Deal Status Code', aggfunc='size')

# Calculate the percentage of 'yes' and 'no' values
pivot_table['won_percentage'] = pivot_table['Won'] / (pivot_table['Won'] + pivot_table['Lost']) * 100
pivot_table['lost_percentage'] = pivot_table['Lost'] / (pivot_table['Won'] + pivot_table['Lost']) * 100

# Sort the pivot table in descending order of 'yes' values
sorted_pivot_table = pivot_table.sort_values('won_percentage', ascending=False)

print(sorted_pivot_table)
# Out:
# Deal Status Code   Lost   Won  won_percentage  lost_percentage
# Manager Name
# Long Bergstrom      2.0   8.0       80.000000        20.000000
# Evalyn Rayner       4.0  15.0       78.947368        21.052632
# Rateesh Singh       2.0   7.0       77.777778        22.222222
# Varsha Arora        2.0   7.0       77.777778        22.222222
# Neha Sharma         4.0  13.0       76.470588        23.529412
# ...                 ...   ...             ...              ...
# rijul aggarwal      2.0   NaN             NaN              NaN
# shafibul           12.0   NaN             NaN              NaN
# shiv kumar          6.0   NaN             NaN              NaN
# shiv shakti singh   2.0   NaN             NaN              NaN
# som dutt            NaN   3.0             NaN              NaN
#
# [278 rows x 4 columns]

# %%
#Feature Selection

# %%
from scipy.stats import chi2_contingency

# %%
table = pd.crosstab(df['Client Category'], df['Deal Status Code'])

# Perform the Chi-square test of independence
chi2, p, dof, expected = chi2_contingency(table)

# Print the results
print("Chi-square statistic =", chi2)
print("p-value =", p)
# Out:
# Chi-square statistic = 331.8130247912921
# p-value = 1.2372963111678756e-47

# %%
table = pd.crosstab(df['Sector'], df['Deal Status Code'])

# Perform the Chi-square test of independence
chi2, p, dof, expected = chi2_contingency(table)

# Print the results
print("Chi-square statistic =", chi2)
print("p-value =", p)
# Out:
# Chi-square statistic = 167.99910626155886
# p-value = 1.3977731163020777e-23

# %%
table = pd.crosstab(df['Location'], df['Deal Status Code'])

# Perform the Chi-square test of independence
chi2, p, dof, expected = chi2_contingency(table)

# Print the results
print("Chi-square statistic =", chi2)
print("p-value =", p)
# Out:
# Chi-square statistic = 135.13775740237165
# p-value = 5.722862610561617e-23

# %%
table = pd.crosstab(df['Solution Type'], df['Deal Status Code'])

# Perform the Chi-square test of independence
chi2, p, dof, expected = chi2_contingency(table)

# Print the results
print("Chi-square statistic =", chi2)
print("p-value =", p)
# Out:
# Chi-square statistic = 649.7308294387967
# p-value = 8.165018988842817e-97

# %%
table = pd.crosstab(df['VP Name'], df['Deal Status Code'])

# Perform the Chi-square test of independence
chi2, p, dof, expected = chi2_contingency(table)

# Print the results
print("Chi-square statistic =", chi2)
print("p-value =", p)
# Out:
# Chi-square statistic = 434.8322932909747
# p-value = 9.522856908968547e-67

# %%
table = pd.crosstab(df['Manager Name'], df['Deal Status Code'])

# Perform the Chi-square test of independence
chi2, p, dof, expected = chi2_contingency(table)

# Print the results
print("Chi-square statistic =", chi2)
print("p-value =", p)
# Out:
# Chi-square statistic = 1203.8302583598997
# p-value = 1.3194666679698546e-115

# %%
# Convert 'Deal Status Code' to binary values: 1 for 'Won', 0 for 'Lost'
df['Deal Won'] = (df['Deal Status Code'] == 'Won').astype(int)

# Calculate the correlation between 'Deal Cost' and 'Deal Won'
correlation = df[['Deal Cost', 'Deal Won']].corr().iloc[0, 1]

print(f"The correlation between 'Deal Cost' and 'Deal Status Code' is {correlation}")
# Out:
# The correlation between 'Deal Cost' and 'Deal Status Code' is -0.015312271868983337

# %%
df
# Out:
#       Client Category Solution Type  Deal Date     Sector Location  \
# 0             Telecom    Solution 7 2012-03-27  Sector 24       L5
# 1             Telecom    Solution 7 2012-09-25  Sector 24       L5
# 2            Internal   Solution 59 2011-08-01  Sector 20   Others
# 3            Internal   Solution 59 2011-04-28  Sector 20   Others
# 4            Internal   Solution 32 2011-06-03  Sector 20   Others
# ...               ...           ...        ...        ...      ...
# 10056       Power ind    Solution 9 2019-03-18   Sector 9       L5
# 10057        Internal    Solution 6 2019-03-04  Sector 20   Others
# 10058       Power ind    Solution 9 2019-02-28   Sector 9       L5
# 10059       Power ind   Solution 62 2019-01-27   Sector 9       L5
# 10060          Others    Solution 9 2019-05-30  Sector 12      L10
#
#                VP Name     Manager Name   Deal Cost Deal Status Code  Deal Won
# 0          Ekta Zutshi  Gopa Trilochana   66.240951              Won         1
# ...

# %%
bins = df['Deal Cost'].quantile([0, .25, .5, .75, 1]).values
labels = ['Small', 'Medium', 'Large', 'Extra Large']

# Create 'Deal Size' feature
df['Deal Size'] = pd.cut(df['Deal Cost'], bins=bins, labels=labels, include_lowest=True)

# %%
df
# Out:
#       Client Category Solution Type  Deal Date     Sector Location  \
# 0             Telecom    Solution 7 2012-03-27  Sector 24       L5
# 1             Telecom    Solution 7 2012-09-25  Sector 24       L5
# 2            Internal   Solution 59 2011-08-01  Sector 20   Others
# 3            Internal   Solution 59 2011-04-28  Sector 20   Others
# 4            Internal   Solution 32 2011-06-03  Sector 20   Others
# ...               ...           ...        ...        ...      ...
# 10056       Power ind    Solution 9 2019-03-18   Sector 9       L5
# 10057        Internal    Solution 6 2019-03-04  Sector 20   Others
# 10058       Power ind    Solution 9 2019-02-28   Sector 9       L5
# 10059       Power ind   Solution 62 2019-01-27   Sector 9       L5
# 10060          Others    Solution 9 2019-05-30  Sector 12      L10
#
#                VP Name     Manager Name   Deal Cost Deal Status Code  \
# 0          Ekta Zutshi  Gopa Trilochana   66.240951              Won
# ...

# %%
won_deals = df[df['Deal Status Code'] == 'Won']

# Calculate win counts
win_counts = won_deals.groupby('Deal Size').size()

# Calculate total counts
total_counts = df.groupby('Deal Size').size()

# Calculate win rate
win_rate = (win_counts / total_counts) * 100

# %%
win_rate.sort_values().plot(kind='barh', figsize=(10, 6))

plt.xlabel('Win Percentage')
plt.ylabel('Deal Size')
plt.title('Win Percentage for Each Deal Size')
plt.show()

# %%
for i in range(len(bins) - 1):
    print(f"{labels[i]}: {bins[i]} to {bins[i+1]}")
# Out:
# Small: 26.62477727038732 to 70.19991316406451
# Medium: 70.19991316406451 to 83.64335635649088
# Large: 83.64335635649088 to 99.2500037598493
# Extra Large: 99.2500037598493 to 142.8251396535265

# %%
df
# Out:
#       Client Category Solution Type  Deal Date     Sector Location  \
# 0             Telecom    Solution 7 2012-03-27  Sector 24       L5
# 1             Telecom    Solution 7 2012-09-25  Sector 24       L5
# 2            Internal   Solution 59 2011-08-01  Sector 20   Others
# 3            Internal   Solution 59 2011-04-28  Sector 20   Others
# 4            Internal   Solution 32 2011-06-03  Sector 20   Others
# ...               ...           ...        ...        ...      ...
# 10056       Power ind    Solution 9 2019-03-18   Sector 9       L5
# 10057        Internal    Solution 6 2019-03-04  Sector 20   Others
# 10058       Power ind    Solution 9 2019-02-28   Sector 9       L5
# 10059       Power ind   Solution 62 2019-01-27   Sector 9       L5
# 10060          Others    Solution 9 2019-05-30  Sector 12      L10
#
#                VP Name     Manager Name   Deal Cost Deal Status Code  \
# 0          Ekta Zutshi  Gopa Trilochana   66.240951              Won
# ...

# %%
df['Deal Date'] = pd.to_datetime(df['Deal Date'])
df['Year'] = df['Deal Date'].dt.year
total_wins = df[df['Deal Status Code'] == 'Won'].groupby('Year').size()
total_deals = df.groupby('Year').size()
win_percent = total_wins / total_deals
fig, ax1 = plt.subplots()

color = 'tab:blue'
ax1.set_xlabel('Year')
ax1.set_ylabel('Total Wins', color=color)
ax1.plot(total_wins.index, total_wins, color=color)
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()
color = 'tab:red'
ax2.set_ylabel('Win Percentage', color=color)
ax2.plot(win_percent.index, win_percent, color=color)
ax2.tick_params(axis='y', labelcolor=color)

fig.tight_layout()
plt.show()

# %%
total_wins = df[df['Deal Status Code'] == 'Won'].groupby('Solution Type').size()
total_deals = df.groupby('Solution Type').size()
win_percent = total_wins / total_deals
win_percent.sort_values().plot(kind='barh', figsize=(10, 15))
plt.xlabel('Win Percentage')
plt.title('Win Percentage by Solution Type')
plt.show()

# %%
df
# Out:
#       Client Category Solution Type  Deal Date     Sector Location  \
# 0             Telecom    Solution 7 2012-03-27  Sector 24       L5
# 1             Telecom    Solution 7 2012-09-25  Sector 24       L5
# 2            Internal   Solution 59 2011-08-01  Sector 20   Others
# 3            Internal   Solution 59 2011-04-28  Sector 20   Others
# 4            Internal   Solution 32 2011-06-03  Sector 20   Others
# ...               ...           ...        ...        ...      ...
# 10056       Power ind    Solution 9 2019-03-18   Sector 9       L5
# 10057        Internal    Solution 6 2019-03-04  Sector 20   Others
# 10058       Power ind    Solution 9 2019-02-28   Sector 9       L5
# 10059       Power ind   Solution 62 2019-01-27   Sector 9       L5
# 10060          Others    Solution 9 2019-05-30  Sector 12      L10
#
#                VP Name     Manager Name   Deal Cost Deal Status Code  \
# 0          Ekta Zutshi  Gopa Trilochana   66.240951              Won
# ...

# %%
df
# Out:
#       Client Category Solution Type  Deal Date     Sector Location  \
# 0             Telecom    Solution 7 2012-03-27  Sector 24       L5
# 1             Telecom    Solution 7 2012-09-25  Sector 24       L5
# 2            Internal   Solution 59 2011-08-01  Sector 20   Others
# 3            Internal   Solution 59 2011-04-28  Sector 20   Others
# 4            Internal   Solution 32 2011-06-03  Sector 20   Others
# ...               ...           ...        ...        ...      ...
# 10056       Power ind    Solution 9 2019-03-18   Sector 9       L5
# 10057        Internal    Solution 6 2019-03-04  Sector 20   Others
# 10058       Power ind    Solution 9 2019-02-28   Sector 9       L5
# 10059       Power ind   Solution 62 2019-01-27   Sector 9       L5
# 10060          Others    Solution 9 2019-05-30  Sector 12      L10
#
#                VP Name     Manager Name   Deal Cost Deal Status Code  \
# 0          Ekta Zutshi  Gopa Trilochana   66.240951              Won
# ...

# %%
df_new = df[['VP Name', 'Manager Name', 'Deal Status Code']].copy()# Create a new column 'Win' to represent if the deal was won

# %%
df['Client Category'] = df['Client Category'].astype('category')
df['Client Category'] = df['Client Category'].cat.codes

df['Solution Type'] = df['Solution Type'].astype('category')
df['Solution Type'] = df['Solution Type'].cat.codes

df['Sector'] = df['Sector'].astype('category')
df['Sector'] = df['Sector'].cat.codes

df['Location'] = df['Location'].astype('category')
df['Location'] = df['Location'].cat.codes

df['VP Name'] = df['VP Name'].astype('category')
df['VP Name'] = df['VP Name'].cat.codes

df['Manager Name'] = df['Manager Name'].astype('category')
df['Manager Name'] = df['Manager Name'].cat.codes

df['Deal Status Code'] = df['Deal Status Code'].astype('category')
df['Deal Status Code'] = df['Deal Status Code'].cat.codes

df['Deal Size'] = df['Deal Size'].astype('category')
df['Deal Size'] = df['Deal Size'].cat.codes

# %%
df
# Out:
#        Client Category  Solution Type  Deal Date  Sector  Location  VP Name  \
# 0                   39             64 2012-03-27      16         7        6
# 1                   39             64 2012-09-25      16         7        6
# 2                   19             54 2011-08-01      12        12        6
# 3                   19             54 2011-04-28      12        12        6
# 4                   19             25 2011-06-03      12        12        6
# ...                ...            ...        ...     ...       ...      ...
# 10056               31             66 2019-03-18      24         7       29
# 10057               19             55 2019-03-04      12        12       29
# 10058               31             66 2019-02-28      24         7       29
# 10059               31             58 2019-01-27      24         7       19
# 10060               28             66 2019-05-30       3         1       34
#
# ...

# %%
#x = df.drop(['Deal Status Code'],axis=1)
y = df['Deal Status Code']

# %%
vp_win_percentage = df.groupby('VP Name')['Deal Status Code'].mean() * 100

# Map the win percentages back to the original DataFrame
df['VP Win Rate'] = df['VP Name'].map(vp_win_percentage)

# Define bins and labels
bins = [0, 25, 50, 75, 100]
labels = ['very Low', 'Low', 'High', 'Very High']

# Bin the win rate percentages
df['VP Win Rate Bin'] = pd.cut(df['VP Win Rate'], bins, labels=labels)

# %%
df
# Out:
#        Client Category  Solution Type  Deal Date  Sector  Location  VP Name  \
# 0                   39             64 2012-03-27      16         7        6
# 1                   39             64 2012-09-25      16         7        6
# 2                   19             54 2011-08-01      12        12        6
# 3                   19             54 2011-04-28      12        12        6
# 4                   19             25 2011-06-03      12        12        6
# ...                ...            ...        ...     ...       ...      ...
# 10056               31             66 2019-03-18      24         7       29
# 10057               19             55 2019-03-04      12        12       29
# 10058               31             66 2019-02-28      24         7       29
# 10059               31             58 2019-01-27      24         7       19
# 10060               28             66 2019-05-30       3         1       34
#
# ...

# %%
client_category_percentage = df.groupby('Client Category')['Deal Status Code'].mean() * 100

# Map the win percentages back to the original DataFrame
df['Client Category Win Rate'] = df['Client Category'].map(client_category_percentage)

# Define bins and labels
bins = [0, 25, 50, 75, 100]
labels = ['very Low', 'Low', 'High', 'Very High']

# Bin the win rate percentages
df['Client Category Win Rate Bin'] = pd.cut(df['Client Category Win Rate'], bins, labels=labels)

# %%
df
# Out:
#        Client Category  Solution Type  Deal Date  Sector  Location  VP Name  \
# 0                   39             64 2012-03-27      16         7        6
# 1                   39             64 2012-09-25      16         7        6
# 2                   19             54 2011-08-01      12        12        6
# 3                   19             54 2011-04-28      12        12        6
# 4                   19             25 2011-06-03      12        12        6
# ...                ...            ...        ...     ...       ...      ...
# 10056               31             66 2019-03-18      24         7       29
# 10057               19             55 2019-03-04      12        12       29
# 10058               31             66 2019-02-28      24         7       29
# 10059               31             58 2019-01-27      24         7       19
# 10060               28             66 2019-05-30       3         1       34
#
# ...

# %%
manager_win_percentage = df.groupby('Manager Name')['Deal Status Code'].mean() * 100

# Map the win percentages back to the original DataFrame
df['Manager Win Rate'] = df['Manager Name'].map(manager_win_percentage)

# Define bins and labels
bins = [0, 25, 50, 75, 100]
labels = ['very Low', 'Low', 'High', 'Very High']

# Bin the win rate percentages
df['Manager Win Rate Bin'] = pd.cut(df['Manager Win Rate'], bins, labels=labels)

# %%
df
# Out:
#        Client Category  Solution Type  Deal Date  Sector  Location  VP Name  \
# 0                   39             64 2012-03-27      16         7        6
# 1                   39             64 2012-09-25      16         7        6
# 2                   19             54 2011-08-01      12        12        6
# 3                   19             54 2011-04-28      12        12        6
# 4                   19             25 2011-06-03      12        12        6
# ...                ...            ...        ...     ...       ...      ...
# 10056               31             66 2019-03-18      24         7       29
# 10057               19             55 2019-03-04      12        12       29
# 10058               31             66 2019-02-28      24         7       29
# 10059               31             58 2019-01-27      24         7       19
# 10060               28             66 2019-05-30       3         1       34
#
# ...

# %%
solution_win_percentage = df.groupby('Solution Type')['Deal Status Code'].mean() * 100

# Map the win percentages back to the original DataFrame
df['Solution Win Rate'] = df['Solution Type'].map(solution_win_percentage)

# Define bins and labels
bins = [0, 25, 50, 75, 100]
labels = ['very Low', 'Low', 'High', 'Very High']

# Bin the win rate percentages
df['Solution Win Rate Bin'] = pd.cut(df['Solution Win Rate'], bins, labels=labels)

# %%
df
# Out:
#        Client Category  Solution Type  Deal Date  Sector  Location  VP Name  \
# 0                   39             64 2012-03-27      16         7        6
# 1                   39             64 2012-09-25      16         7        6
# 2                   19             54 2011-08-01      12        12        6
# 3                   19             54 2011-04-28      12        12        6
# 4                   19             25 2011-06-03      12        12        6
# ...                ...            ...        ...     ...       ...      ...
# 10056               31             66 2019-03-18      24         7       29
# 10057               19             55 2019-03-04      12        12       29
# 10058               31             66 2019-02-28      24         7       29
# 10059               31             58 2019-01-27      24         7       19
# 10060               28             66 2019-05-30       3         1       34
#
# ...

# %%
sector_win_percentage = df.groupby('Sector')['Deal Status Code'].mean() * 100

# Map the win percentages back to the original DataFrame
df['Sector Win Rate'] = df['Sector'].map(sector_win_percentage)

# Define bins and labels
bins = [0, 25, 50, 75, 100]
labels = ['very Low', 'Low', 'High', 'Very High']

# Bin the win rate percentages
df['Sector Win Rate Bin'] = pd.cut(df['Sector Win Rate'], bins, labels=labels)

# %%
df
# Out:
#        Client Category  Solution Type  Deal Date  Sector  Location  VP Name  \
# 0                   39             64 2012-03-27      16         7        6
# 1                   39             64 2012-09-25      16         7        6
# 2                   19             54 2011-08-01      12        12        6
# 3                   19             54 2011-04-28      12        12        6
# 4                   19             25 2011-06-03      12        12        6
# ...                ...            ...        ...     ...       ...      ...
# 10056               31             66 2019-03-18      24         7       29
# 10057               19             55 2019-03-04      12        12       29
# 10058               31             66 2019-02-28      24         7       29
# 10059               31             58 2019-01-27      24         7       19
# 10060               28             66 2019-05-30       3         1       34
#
# ...

# %%
location_win_percentage = df.groupby('Location')['Deal Status Code'].mean() * 100

# Map the win percentages back to the original DataFrame
df['Location Win Rate'] = df['Location'].map(location_win_percentage)

# Define bins and labels
bins = [0, 25, 50, 75, 100]
labels = ['very Low', 'Low', 'High', 'Very High']

# Bin the win rate percentages
df['Location Win Rate Bin'] = pd.cut(df['Location Win Rate'], bins, labels=labels)

# %%
df
# Out:
#        Client Category  Solution Type  Deal Date  Sector  Location  VP Name  \
# 0                   39             64 2012-03-27      16         7        6
# 1                   39             64 2012-09-25      16         7        6
# 2                   19             54 2011-08-01      12        12        6
# 3                   19             54 2011-04-28      12        12        6
# 4                   19             25 2011-06-03      12        12        6
# ...                ...            ...        ...     ...       ...      ...
# 10056               31             66 2019-03-18      24         7       29
# 10057               19             55 2019-03-04      12        12       29
# 10058               31             66 2019-02-28      24         7       29
# 10059               31             58 2019-01-27      24         7       19
# 10060               28             66 2019-05-30       3         1       34
#
# ...

# %%
df['Client Category Win Rate Bin'] = df['Client Category Win Rate Bin'].astype('category')
df['Client Category Win Rate Bin'] = df['Client Category Win Rate Bin'].cat.codes

df['Manager Win Rate Bin'] = df['Manager Win Rate Bin'].astype('category')
df['Manager Win Rate Bin'] = df['Manager Win Rate Bin'].cat.codes

df['Solution Win Rate Bin'] = df['Solution Win Rate Bin'].astype('category')
df['Solution Win Rate Bin'] = df['Solution Win Rate Bin'].cat.codes

df['Sector Win Rate Bin'] = df['Sector Win Rate Bin'].astype('category')
df['Sector Win Rate Bin'] = df['Sector Win Rate Bin'].cat.codes

df['Location Win Rate Bin'] = df['Location Win Rate Bin'].astype('category')
df['Location Win Rate Bin'] = df['Location Win Rate Bin'].cat.codes

df['VP Win Rate Bin'] = df['VP Win Rate Bin'].astype('category')
df['VP Win Rate Bin'] = df['VP Win Rate Bin'].cat.codes

# %%
df
# Out:
#        Client Category  Solution Type  Deal Date  Sector  Location  VP Name  \
# 0                   39             64 2012-03-27      16         7        6
# 1                   39             64 2012-09-25      16         7        6
# 2                   19             54 2011-08-01      12        12        6
# 3                   19             54 2011-04-28      12        12        6
# 4                   19             25 2011-06-03      12        12        6
# ...                ...            ...        ...     ...       ...      ...
# 10056               31             66 2019-03-18      24         7       29
# 10057               19             55 2019-03-04      12        12       29
# 10058               31             66 2019-02-28      24         7       29
# 10059               31             58 2019-01-27      24         7       19
# 10060               28             66 2019-05-30       3         1       34
#
# ...

# %%
#x = df.drop(['Deal Status Code'],axis=1)
y = df['Deal Status Code']

# %%
df
# Out:
#        Client Category  Solution Type  Deal Date  Sector  Location  VP Name  \
# 0                   39             64 2012-03-27      16         7        6
# 1                   39             64 2012-09-25      16         7        6
# 2                   19             54 2011-08-01      12        12        6
# 3                   19             54 2011-04-28      12        12        6
# 4                   19             25 2011-06-03      12        12        6
# ...                ...            ...        ...     ...       ...      ...
# 10056               31             66 2019-03-18      24         7       29
# 10057               19             55 2019-03-04      12        12       29
# 10058               31             66 2019-02-28      24         7       29
# 10059               31             58 2019-01-27      24         7       19
# 10060               28             66 2019-05-30       3         1       34
#
# ...

# %%
x = df.drop(['Deal Status Code','Deal Date'],axis=1)

# %%
x
# Out:
#        Client Category  Solution Type  Sector  Location  VP Name  \
# 0                   39             64      16         7        6
# 1                   39             64      16         7        6
# 2                   19             54      12        12        6
# 3                   19             54      12        12        6
# 4                   19             25      12        12        6
# ...                ...            ...     ...       ...      ...
# 10056               31             66      24         7       29
# 10057               19             55      12        12       29
# 10058               31             66      24         7       29
# 10059               31             58      24         7       19
# 10060               28             66       3         1       34
#
#        Manager Name   Deal Cost  Deal Won  Deal Size  Year  ...  \
# 0                82   66.240951         1          0  2012  ...
# ...

# %%
#x = df.drop(['Deal Won','Deal Status Code','Deal Date','Client Category Win Rate','Manager Win Rate','Solution Win Rate','Sector Win Rate','Location Win Rate'],axis=1)

# %%
x
# Out:
#        Client Category  Solution Type  Sector  Location  VP Name  \
# 0                   39             64      16         7        6
# 1                   39             64      16         7        6
# 2                   19             54      12        12        6
# 3                   19             54      12        12        6
# 4                   19             25      12        12        6
# ...                ...            ...     ...       ...      ...
# 10056               31             66      24         7       29
# 10057               19             55      12        12       29
# 10058               31             66      24         7       29
# 10059               31             58      24         7       19
# 10060               28             66       3         1       34
#
#        Manager Name   Deal Cost  Deal Won  Deal Size  Year  ...  \
# 0                82   66.240951         1          0  2012  ...
# ...

# %%
columns_to_drop=['Client Category Win Rate','Manager Win Rate','Solution Win Rate','Sector Win Rate','Location Win Rate']

# %%
x.drop(columns=columns_to_drop,inplace=True)

# %%
x
# Out:
#        Client Category  Solution Type  Sector  Location  VP Name  \
# 0                   39             64      16         7        6
# 1                   39             64      16         7        6
# 2                   19             54      12        12        6
# 3                   19             54      12        12        6
# 4                   19             25      12        12        6
# ...                ...            ...     ...       ...      ...
# 10056               31             66      24         7       29
# 10057               19             55      12        12       29
# 10058               31             66      24         7       29
# 10059               31             58      24         7       19
# 10060               28             66       3         1       34
#
#        Manager Name   Deal Cost  Deal Won  Deal Size  Year  VP Win Rate  \
# 0                82   66.240951         1          0  2012    62.545455
# ...

# %%
x.drop(columns=['VP Win Rate','Deal Won'] ,inplace=True)

# %%
x
# Out:
#        Client Category  Solution Type  Sector  Location  VP Name  \
# 0                   39             64      16         7        6
# 1                   39             64      16         7        6
# 2                   19             54      12        12        6
# 3                   19             54      12        12        6
# 4                   19             25      12        12        6
# ...                ...            ...     ...       ...      ...
# 10056               31             66      24         7       29
# 10057               19             55      12        12       29
# 10058               31             66      24         7       29
# 10059               31             58      24         7       19
# 10060               28             66       3         1       34
#
#        Manager Name   Deal Cost  Deal Size  Year  VP Win Rate Bin  \
# 0                82   66.240951          0  2012                2
# ...

# %%
y
# Out:
# 0        1
# 1        1
# 2        0
# 3        0
# 4        0
#         ..
# 10056    0
# 10057    1
# 10058    0
# 10059    1
# 10060    0
# Name: Deal Status Code, Length: 10047, dtype: int8

# %%
x1
# Out:
# array([[ 1.39637826,  1.29851309,  0.78530406, ..., -0.25797252,
#         -0.08357862,  0.16234566],
#        [ 1.39637826,  1.29851309,  0.78530406, ..., -0.25797252,
#         -0.08357862,  0.16234566],
#        [-0.33255296,  0.86183028,  0.01693966, ..., -0.25797252,
#          2.67863984,  0.16234566],
#        ...,
#        [ 0.70480577,  1.38584965,  2.32203287, ..., -0.25797252,
#         -0.08357862,  0.16234566],
#        [ 0.70480577,  1.0365034 ,  2.32203287, ..., -0.25797252,
#         -0.08357862,  0.16234566],
#        [ 0.44546609,  1.38584965, -1.71188025, ..., -0.25797252,
#         -0.08357862,  0.16234566]])

# %%
#Splitting into training & testing data (75% Train & 25% Test)
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x1, y, train_size=0.75 , random_state=100)

# %%
from sklearn.linear_model import LogisticRegression
logit = LogisticRegression()
logit.fit(x_train , y_train)
# Out:
# LogisticRegression()

# %%
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score

# %%
y_pred_log_test = logit.predict(x_test)
y_pred_log_train = logit.predict(x_train)

# %%
cm_train = confusion_matrix(y_train, y_pred_log_train)

# Calculate confusion matrix for test set
cm_test = confusion_matrix(y_test, y_pred_log_test)

# Plot confusion matrix for training set
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
sns.heatmap(cm_train, annot=True, fmt="d", cmap="Blues", xticklabels=nm.unique(y_train), yticklabels=nm.unique(y_train))
plt.title('Confusion Matrix - Training Set')
plt.xlabel('Predicted')
plt.ylabel('Actual')

# Plot confusion matrix for test set
plt.subplot(1, 2, 2)
sns.heatmap(cm_test, annot=True, fmt="d", cmap="Blues", xticklabels=nm.unique(y_test), yticklabels=nm.unique(y_test))
plt.title('Confusion Matrix - Test Set')
plt.xlabel('Predicted')
plt.ylabel('Actual')

plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import accuracy_score

print('Test Model accuracy score: {0:0.4f}'. format(accuracy_score(y_test, y_pred_log_test)))
# Out:
# Test Model accuracy score: 0.7046

# %%
print('Training-set accuracy score: {0:0.4f}'. format(accuracy_score(y_train, y_pred_log_train)))
# Out:
# Training-set accuracy score: 0.6994

# %%
print(classification_report(y_test,y_pred_log_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.73      0.85      0.78      1589
#            1       0.64      0.46      0.53       923
#
#     accuracy                           0.70      2512
#    macro avg       0.68      0.65      0.66      2512
# weighted avg       0.70      0.70      0.69      2512

# %%
from sklearn.model_selection import cross_val_score
lr_scores = cross_val_score(logit, x, y, cv=5)
print("Logistic Regression cross-validation scores: ", lr_scores)
# Out:
# /Users/hemangjoshi/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/hemangjoshi/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=101, max_depth=15)
rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier(max_depth=15, n_estimators=101)

# %%
y_pred_rf_train = rf.predict(x_train)
y_pred_rf_test = rf.predict(x_test)

# %%
cm_train = confusion_matrix(y_train, y_pred_rf_train)

# Calculate confusion matrix for test set
cm_test = confusion_matrix(y_test, y_pred_rf_test)

# Plot confusion matrix for training set
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
sns.heatmap(cm_train, annot=True, fmt="d", cmap="Blues", xticklabels=nm.unique(y_train), yticklabels=nm.unique(y_train))
plt.title('Confusion Matrix - Training Set')
plt.xlabel('Predicted')
plt.ylabel('Actual')

# Plot confusion matrix for test set
plt.subplot(1, 2, 2)
sns.heatmap(cm_test, annot=True, fmt="d", cmap="Blues", xticklabels=nm.unique(y_test), yticklabels=nm.unique(y_test))
plt.title('Confusion Matrix - Test Set')
plt.xlabel('Predicted')
plt.ylabel('Actual')

plt.tight_layout()
plt.show()

# %%
print('Training-set accuracy score: {0:0.4f}'. format(accuracy_score(y_train, y_pred_rf_train)))
# Out:
# Training-set accuracy score: 0.9192

# %%
print('Training-set accuracy score: {0:0.4f}'. format(accuracy_score(y_test, y_pred_rf_test)))
# Out:
# Training-set accuracy score: 0.8029

# %%
# Get feature importances
importances = rf.feature_importances_

# Convert the importances into a DataFrame
feature_importances = pd.DataFrame({'Feature': x.columns, 'Importance': importances})

# Sort the DataFrame to reveal the top 5 features
top_5_features = feature_importances.sort_values(by='Importance', ascending=False).head(5)

print(top_5_features)
# Out:
#                  Feature  Importance
# 6              Deal Cost    0.186563
# 11  Manager Win Rate Bin    0.122415
# 5           Manager Name    0.096605
# 1          Solution Type    0.078248
# 0        Client Category    0.074920

# %%
feature_importances = feature_importances.sort_values(by='Importance', ascending=True)

plt.figure(figsize=(10, 6))
plt.barh(feature_importances['Feature'], feature_importances['Importance'], color='skyblue')
plt.xlabel('Importance')
plt.ylabel('Feature')
plt.title('Feature Importances')
plt.show()

# %%
print(classification_report(y_test,y_pred_rf_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.94      0.86      1589
#            1       0.84      0.58      0.68       923
#
#     accuracy                           0.80      2512
#    macro avg       0.81      0.76      0.77      2512
# weighted avg       0.81      0.80      0.79      2512

# %%
rf_scores = cross_val_score(rf, x, y, cv=5)
print("Random Forest cross-validation scores: ", rf_scores)
# Out:
# Random Forest cross-validation scores:  [0.70945274 0.70945274 0.69885515 0.71478347 0.70383275]

# %%
x
# Out:
#        Client Category  Solution Type  Sector  Location  VP Name  \
# 0                   39             64      16         7        6
# 1                   39             64      16         7        6
# 2                   19             54      12        12        6
# 3                   19             54      12        12        6
# 4                   19             25      12        12        6
# ...                ...            ...     ...       ...      ...
# 10056               31             66      24         7       29
# 10057               19             55      12        12       29
# 10058               31             66      24         7       29
# 10059               31             58      24         7       19
# 10060               28             66       3         1       34
#
#        Manager Name   Deal Cost  Deal Size  Year  VP Win Rate Bin  \
# 0                82   66.240951          0  2012                2
# ...

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model = DecisionTreeClassifier(max_depth=5)
model.fit(x_train, y_train)

#Predict on train data
y_pred_train= model.predict(x_train)

# Predict on test data
y_pred_dt = model.predict(x_test)


#take Train Data performance
accuracy_Train_dt = accuracy_score(y_train, y_pred_train)

# Evaluate model performance
accuracy_dt = accuracy_score(y_test, y_pred_dt)

# %%
cm_train = confusion_matrix(y_train, y_pred_train)

# Calculate confusion matrix for test set
cm_test = confusion_matrix(y_test, y_pred_dt)

# Plot confusion matrix for training set
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
sns.heatmap(cm_train, annot=True, fmt="d", cmap="Blues", xticklabels=nm.unique(y_train), yticklabels=nm.unique(y_train))
plt.title('Confusion Matrix - Training Set')
plt.xlabel('Predicted')
plt.ylabel('Actual')

# Plot confusion matrix for test set
plt.subplot(1, 2, 2)
sns.heatmap(cm_test, annot=True, fmt="d", cmap="Blues", xticklabels=nm.unique(y_test), yticklabels=nm.unique(y_test))
plt.title('Confusion Matrix - Test Set')
plt.xlabel('Predicted')
plt.ylabel('Actual')

plt.tight_layout()
plt.show()

# %%
print(f"Training Data Accuracy Using Descision Tree: {accuracy_Train_dt:.4f}")
# Out:
# Training Data Accuracy Using Descision Tree: 0.6940

# %%
print(f"Decision Tree Accuracy: {accuracy_dt:.4f}")
# Out:
# Decision Tree Accuracy: 0.6887

# %%
print(classification_report(y_test,y_pred_dt))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.73      0.81      0.77      1589
#            1       0.60      0.48      0.53       923
#
#     accuracy                           0.69      2512
#    macro avg       0.66      0.64      0.65      2512
# weighted avg       0.68      0.69      0.68      2512

# %%
dc_scores = cross_val_score(model, x, y, cv=5)
print("Decision Tree cross-validation scores: ", dc_scores)
# Out:
# Decision Tree cross-validation scores:  [0.70497512 0.69751244 0.67346939 0.67247387 0.69238427]

# %%
df_new['Win'] = df_new['Deal Status Code'].apply(lambda x: 1 if x == 'Won' else 0)

# Calculate total deals and wins for each VP and Manager combination
grouped = df_new.groupby(['VP Name', 'Manager Name'])
total_deals = grouped.size()
total_wins = grouped['Win'].sum()

# Calculate win rate
win_rate = (total_wins / total_deals)*100

# Combine into a DataFrame
summary = pd.DataFrame({
    'Total Deals': total_deals,
    'Total Wins': total_wins,
    'Win Rate': win_rate
})

# Sort by win rate and total deals
summary = summary.sort_values(by=['Win Rate', 'Total Deals'], ascending=False)

# Get the top 5 combinations
top_5_combinations = summary.head(5)

print(top_5_combinations)
# Out:
#                                Total Deals  Total Wins  Win Rate
# VP Name         Manager Name
# neeraj kumar    gurmit singh            18          18     100.0
# Ekta Zutshi     Ekta Zutshi             10          10     100.0
# Rudraksh Sharma Preetan Gujar           10          10     100.0
# Russell Dahlen  Martin Cheyne           10          10     100.0
# som dutt        Roop Sachdeva            9           9     100.0

# %%
top_5_combinations[['Win Rate', 'Total Deals']].plot(kind='bar', subplots=True, layout=(2,1), sharex=True, figsize=(10,8))
plt.xlabel('VP and Manager Combination')
plt.ylabel('Value')
plt.title('Top 5 VP and Manager Combinations')
plt.show()
